# %%
import requests
r = requests.get("https://api.cricapi.com/v1/currentMatches?apikey=92ae6615-1092-4146-b76a-15e50c34d85d&offset=0")
print(r.json())
# Out:
# {'apikey': '92ae6615-1092-4146-b76a-15e50c34d85d', 'data': [{'id': '331abf83-6d41-4134-8707-4bee63e56743', 'name': 'West Indies Women vs Australia Women, 2nd ODI, Australia Women tour of West Indies, 2026', 'status': 'Australia Women won by 90 runs', 'venue': 'Warner Park, Basseterre, St Kitts', 'date': '2026-03-29', 'dateTimeGMT': '2026-03-29T18:00:00', 'teams': ['West Indies Women', 'Australia Women'], 'teamInfo': [{'name': 'Australia Women', 'shortname': 'AUSW', 'img': 'https://g.cricapi.com/iapi/7-637877070884402012.webp?w=48'}, {'name': 'West Indies Women', 'shortname': 'WIW', 'img': 'https://g.cricapi.com/iapi/102-637877078650138806.webp?w=48'}], 'score': [{'r': 269, 'w': 7, 'o': 50, 'inning': 'australia women Inning 1'}, {'r': 179, 'w': 10, 'o': 46, 'inning': 'West Indies Women,Australia Women Inning 1'}], 'series_id': '5907f21d-edb7-4219-bb81-1dadb1a13b7d', 'fantasyEnabled': False, 'bbbEnabled': False, 'hasSquad': False, 'matchStarted': True, 'matchEnded': True}, {'id': '8149
# ...
